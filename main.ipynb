# %%
import csv
from funcoes import ler_csv
from funcoes import tratar_nulos
from funcoes import padronizar_categorias
from funcoes import tratar_nulos
from funcoes import calcular_media
from funcoes import tratar_dimensoes_nulas

# %%
dados = ler_csv("olist_products_dataset.csv")

print(dados[0])
print(len(dados))
# Out:
# {'product_id': '1e9e8ef04dbcff4541ed26657ea517e5', 'product_category_name': 'perfumaria', 'product_name_lenght': '40', 'product_description_lenght': '287', 'product_photos_qty': '1', 'product_weight_g': '225', 'product_length_cm': '16', 'product_height_cm': '10', 'product_width_cm': '14'}
# 32951

# %%
dados_nulos_tratados, total_nulos_corrigidos = tratar_nulos(dados)
print(total_nulos_corrigidos)
# Out:
# 610

# %%
dados_padronizados = padronizar_categorias(dados_nulos_tratados)

# %%
dimensoes_tratadas, linhas_corrigidas = tratar_dimensoes_nulas(dados_nulos_tratados)

# %%
print(total_nulos_corrigidos)
print(linhas_corrigidas)
print(dimensoes_tratadas[0])
# Out:
# 610
# 8
# {'product_id': '1e9e8ef04dbcff4541ed26657ea517e5', 'product_category_name': 'perfumaria', 'product_name_lenght': '40', 'product_description_lenght': '287', 'product_photos_qty': '1', 'product_weight_g': '225', 'product_length_cm': '16', 'product_height_cm': '10', 'product_width_cm': '14'}
